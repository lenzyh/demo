# %%
from github import Github
import os

# Replace these values with your own
github_token = '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'
repo_name = 'lenzyh/demo'
local_folder_path = 'C:/Users/YeHernYeow/Desktop/Demo'

# Initialize the GitHub instance using your personal access token
g = Github(github_token)

# Get the repository
repo = g.get_repo(repo_name)

# List all files in the local folder
files_to_upload = [f for f in os.listdir(local_folder_path) if os.path.isfile(os.path.join(local_folder_path, f))]

# Upload each file to the repository by first deleting the existing file (if it exists)
for file_name in files_to_upload:
    file_path = os.path.join(local_folder_path, file_name)
    with open(file_path, 'rb') as file:
        content = file.read()

    # Specify the path in the repository where the file will be uploaded/updated
    github_file_path = f'data/{file_name}'  # Change this to your desired path

    try:
        existing_file = repo.get_contents(github_file_path)
        repo.delete_file(existing_file.path, f'Delete {file_name}', existing_file.sha, branch='main')
        print(f'Deleted existing {file_name} in GitHub repository.')

    except Exception:
        pass

    # Create a new file
    repo.create_file(github_file_path, f'Upload {file_name}', content, branch='main')
    print(f'Uploaded {file_name} to GitHub repository.')

print('All files uploaded/updated to GitHub repository successfully!')
# Out:
# Deleted existing 1_BonusTrends_TopicWordClouds.png in GitHub repository.
# Uploaded 1_BonusTrends_TopicWordClouds.png to GitHub repository.
# Deleted existing 1_ComplaintTrends_TopicWordClouds.png in GitHub repository.
# Uploaded 1_ComplaintTrends_TopicWordClouds.png to GitHub repository.
# Deleted existing 2_BonusTrends_TopicWordScore.html in GitHub repository.
# Uploaded 2_BonusTrends_TopicWordScore.html to GitHub repository.
# Deleted existing 2_ComplaintTrends_TopicWordScore.html in GitHub repository.
# Uploaded 2_ComplaintTrends_TopicWordScore.html to GitHub repository.
# Deleted existing 3_BonusTrends_TopicGrouping.html in GitHub repository.
# Uploaded 3_BonusTrends_TopicGrouping.html to GitHub repository.
# Deleted existing 3_ComplaintTrends_TopicGrouping.html in GitHub repository.
# Uploaded 3_ComplaintTrends_TopicGrouping.html to GitHub repository.
# Deleted existing 4_BonusTrends_InterDisMap.html in GitHub repository.
# Uploaded 4_BonusTrends_InterDisMap.html to GitHub repository.
# Deleted existing 4_ComplaintTrends_InterDisMap.html in GitHub repository.
# Uploaded 4_ComplaintTrends_InterDisMap.html to GitHub repository.
# Deleted existing 5_BonusTrends_DetailedDocMap.html in GitHub repository.
# Uploaded 5_BonusTrends_DetailedDocMap.html to GitHub repository.
# Deleted existing 5_ComplaintTrends_DetailedDocMap.html in GitHub repository.
# Uploaded 5_ComplaintTrends_DetailedDocMap.html to GitHub repository.
# Deleted existing Best_Online_Casinos.csv in GitHub repository.
# Uploaded Best_Online_Casinos.csv to GitHub repository.
# Deleted existing crypto_reddit_comment.csv in GitHub repository.
# Uploaded crypto_reddit_comment.csv to GitHub repository.
# Deleted existing headline.csv in GitHub repository.
# Uploaded headline.csv to GitHub repository.
# Deleted existing headline_nba.csv in GitHub repository.
# Uploaded headline_nba.csv to GitHub repository.
# Deleted existing Intertopic.html in GitHub repository.
# Uploaded Intertopic.html to GitHub repository.
# Deleted existing match.csv in GitHub repository.
# Uploaded match.csv to GitHub repository.
# Deleted existing match.jpg in GitHub repository.
# Uploaded match.jpg to GitHub repository.
# Deleted existing match.xlsx in GitHub repository.
# Uploaded match.xlsx to GitHub repository.
# Deleted existing Online_Casino_Bonuses.csv in GitHub repository.
# Uploaded Online_Casino_Bonuses.csv to GitHub repository.
# Deleted existing Online_Gambling_News.csv in GitHub repository.
# Uploaded Online_Gambling_News.csv to GitHub repository.
# Deleted existing Open_Casino_Complaints.csv in GitHub repository.
# Uploaded Open_Casino_Complaints.csv to GitHub repository.
# Deleted existing player.csv in GitHub repository.
# Uploaded player.csv to GitHub repository.
# Deleted existing player.jpg in GitHub repository.
# Uploaded player.jpg to GitHub repository.
# Deleted existing player.xlsx in GitHub repository.
# Uploaded player.xlsx to GitHub repository.
# Deleted existing Sentiment_Crypto.csv in GitHub repository.
# Uploaded Sentiment_Crypto.csv to GitHub repository.
# Deleted existing sportsdata.csv in GitHub repository.
# Uploaded sportsdata.csv to GitHub repository.
# Deleted existing sport_topic.html in GitHub repository.
# Uploaded sport_topic.html to GitHub repository.
# Deleted existing trans_title.csv in GitHub repository.
# Uploaded trans_title.csv to GitHub repository.
# All files uploaded/updated to GitHub repository successfully!
